# %% [markdown]
# <a href="https://colab.research.google.com/github/AliyaZubova/Lab1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# импорт модулей
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import sklearn
# загрузка датасета
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# создание своего разбиения датасета
from sklearn.model_selection import train_test_split
# объединяем в один набор
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))
# разбиваем по вариантам
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size = 10000,
train_size = 60000,
random_state = 123)
# вывод размерностей
print('Shape of X train:', X_train.shape)
print('Shape of y train:', y_train.shape)
# вывод изображения
plt.imshow(X_train[123], cmap=plt.get_cmap('gray'))
plt.show()
# вывод метки для этого изображения
print(y_train[123])
# развернем каждое изображение 28*28 в вектор 784
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels) / 255
X_test = X_test.reshape(X_test.shape[0], num_pixels) / 255
print('Shape of transformed X train:', X_train.shape)
# переведем метки в one-hot
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
print('Shape of transformed y train:', y_train.shape)
num_classes = y_train.shape[1]
from keras.models import Sequential
from keras.layers import Dense
# 1. создаем модель - объявляем ее объектом класса Sequential
model = Sequential()
# 2. добавляем первый скрытый слой
model.add(Dense(units=300, input_dim=num_pixels, activation='sigmoid'))
# 3. добавляем второй скрытый слой
model.add(Dense(units=100, activation='sigmoid'))
# 4. добавляем выходной слой
model.add(Dense(units=num_classes, activation='softmax'))
# 5. компилируем модель
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
# вывод информации об архитектуре модели
print(model.summary())
# Обучаем модель
H = model.fit(X_train, y_train, validation_split=0.1, epochs=100)
# вывод графика ошибки по эпохам
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend(['train_loss', 'val_loss'])
plt.title('Loss by epochs')
plt.show()
# Оценка качества работы модели на тестовых данных
scores = model.evaluate(X_test, y_test)
print('Loss on test data:', scores[0])
print('Accuracy on test data:', scores[1])
# вывод тестового изображения и результата распознавания
n = 123
result = model.predict(X_test[n:n+1])
print('NN output:', result)
plt.imshow(X_test[n].reshape(28,28), cmap=plt.get_cmap('gray'))
plt.show()
print('Real mark: ', str(np.argmax(y_test[n])))
print('NN answer: ', str(np.argmax(result)))
# загрузка собственного изображения
from PIL import Image
file_data = Image.open('test.png')
file_data = file_data.convert('L') # перевод в градации серого
test_img = np.array(file_data)
# вывод собственного изображения
plt.imshow(test_img, cmap=plt.get_cmap('gray'))
plt.show()
# предобработка
test_img = test_img / 255
test_img = test_img.reshape(1, num_pixels)
# распознавание
result = model.predict(test_img)
print('I think it\'s ', np.argmax(result))
# Out:
# Shape of X train: (60000, 28, 28)
# Shape of y train: (60000,)
# 4
# Shape of transformed X train: (60000, 784)
# Shape of transformed y train: (60000, 10)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 300)               235500
#
#  dense_4 (Dense)             (None, 100)               30100
#
#  dense_5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.1499 - accuracy: 0.4053 - val_loss: 1.9299 - val_accuracy: 0.5675
# Epoch 2/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 1.5631 - accuracy: 0.6689 - val_loss: 1.2157 - val_accuracy: 0.7352
# Epoch 3/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.9936 - accuracy: 0.7716 - val_loss: 0.8252 - val_accuracy: 0.7988
# Epoch 4/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.7225 - accuracy: 0.8233 - val_loss: 0.6404 - val_accuracy: 0.8388
# Epoch 5/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.5849 - accuracy: 0.8518 - val_loss: 0.5401 - val_accuracy: 0.8588
# Epoch 6/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5054 - accuracy: 0.8687 - val_loss: 0.4761 - val_accuracy: 0.8742
# Epoch 7/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.4547 - accuracy: 0.8781 - val_loss: 0.4365 - val_accuracy: 0.8827
# Epoch 8/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.4204 - accuracy: 0.8849 - val_loss: 0.4096 - val_accuracy: 0.8892
# Epoch 9/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.3962 - accuracy: 0.8897 - val_loss: 0.3892 - val_accuracy: 0.8953
# Epoch 10/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.3781 - accuracy: 0.8933 - val_loss: 0.3729 - val_accuracy: 0.8982
# Epoch 11/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.3639 - accuracy: 0.8979 - val_loss: 0.3602 - val_accuracy: 0.9020
# Epoch 12/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3520 - accuracy: 0.8995 - val_loss: 0.3506 - val_accuracy: 0.9040
# Epoch 13/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.3424 - accuracy: 0.9024 - val_loss: 0.3436 - val_accuracy: 0.9048
# Epoch 14/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3337 - accuracy: 0.9043 - val_loss: 0.3350 - val_accuracy: 0.9070
# Epoch 15/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3262 - accuracy: 0.9064 - val_loss: 0.3272 - val_accuracy: 0.9088
# Epoch 16/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.3195 - accuracy: 0.9080 - val_loss: 0.3220 - val_accuracy: 0.9105
# Epoch 17/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.3134 - accuracy: 0.9092 - val_loss: 0.3166 - val_accuracy: 0.9107
# Epoch 18/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3076 - accuracy: 0.9112 - val_loss: 0.3123 - val_accuracy: 0.9113
# Epoch 19/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.3027 - accuracy: 0.9122 - val_loss: 0.3067 - val_accuracy: 0.9152
# Epoch 20/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2978 - accuracy: 0.9136 - val_loss: 0.3018 - val_accuracy: 0.9163
# Epoch 21/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2932 - accuracy: 0.9151 - val_loss: 0.2980 - val_accuracy: 0.9172
# Epoch 22/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2887 - accuracy: 0.9164 - val_loss: 0.2943 - val_accuracy: 0.9183
# Epoch 23/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.2848 - accuracy: 0.9180 - val_loss: 0.2910 - val_accuracy: 0.9180
# Epoch 24/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2808 - accuracy: 0.9183 - val_loss: 0.2871 - val_accuracy: 0.9198
# Epoch 25/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2772 - accuracy: 0.9195 - val_loss: 0.2833 - val_accuracy: 0.9195
# Epoch 26/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2736 - accuracy: 0.9208 - val_loss: 0.2800 - val_accuracy: 0.9200
# Epoch 27/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2703 - accuracy: 0.9212 - val_loss: 0.2789 - val_accuracy: 0.9200
# Epoch 28/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2670 - accuracy: 0.9228 - val_loss: 0.2757 - val_accuracy: 0.9203
# Epoch 29/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2639 - accuracy: 0.9233 - val_loss: 0.2710 - val_accuracy: 0.9228
# Epoch 30/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2607 - accuracy: 0.9245 - val_loss: 0.2692 - val_accuracy: 0.9235
# Epoch 31/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2578 - accuracy: 0.9247 - val_loss: 0.2670 - val_accuracy: 0.9255
# Epoch 32/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2548 - accuracy: 0.9260 - val_loss: 0.2632 - val_accuracy: 0.9238
# Epoch 33/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2520 - accuracy: 0.9269 - val_loss: 0.2617 - val_accuracy: 0.9237
# Epoch 34/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2494 - accuracy: 0.9273 - val_loss: 0.2581 - val_accuracy: 0.9253
# Epoch 35/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2466 - accuracy: 0.9286 - val_loss: 0.2561 - val_accuracy: 0.9255
# Epoch 36/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2439 - accuracy: 0.9291 - val_loss: 0.2541 - val_accuracy: 0.9270
# Epoch 37/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2413 - accuracy: 0.9297 - val_loss: 0.2508 - val_accuracy: 0.9275
# Epoch 38/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2387 - accuracy: 0.9305 - val_loss: 0.2483 - val_accuracy: 0.9287
# Epoch 39/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2362 - accuracy: 0.9316 - val_loss: 0.2482 - val_accuracy: 0.9283
# Epoch 40/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.2336 - accuracy: 0.9327 - val_loss: 0.2435 - val_accuracy: 0.9305
# Epoch 41/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2313 - accuracy: 0.9329 - val_loss: 0.2417 - val_accuracy: 0.9302
# Epoch 42/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2289 - accuracy: 0.9335 - val_loss: 0.2398 - val_accuracy: 0.9327
# Epoch 43/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2265 - accuracy: 0.9344 - val_loss: 0.2381 - val_accuracy: 0.9315
# Epoch 44/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2240 - accuracy: 0.9351 - val_loss: 0.2363 - val_accuracy: 0.9323
# Epoch 45/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2220 - accuracy: 0.9356 - val_loss: 0.2341 - val_accuracy: 0.9313
# Epoch 46/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2196 - accuracy: 0.9363 - val_loss: 0.2308 - val_accuracy: 0.9328
# Epoch 47/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2174 - accuracy: 0.9375 - val_loss: 0.2292 - val_accuracy: 0.9342
# Epoch 48/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2150 - accuracy: 0.9378 - val_loss: 0.2269 - val_accuracy: 0.9333
# Epoch 49/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2130 - accuracy: 0.9386 - val_loss: 0.2263 - val_accuracy: 0.9350
# Epoch 50/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2109 - accuracy: 0.9393 - val_loss: 0.2229 - val_accuracy: 0.9352
# Epoch 51/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2086 - accuracy: 0.9395 - val_loss: 0.2223 - val_accuracy: 0.9347
# Epoch 52/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.2066 - accuracy: 0.9406 - val_loss: 0.2194 - val_accuracy: 0.9360
# Epoch 53/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2045 - accuracy: 0.9409 - val_loss: 0.2180 - val_accuracy: 0.9365
# Epoch 54/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.2025 - accuracy: 0.9416 - val_loss: 0.2163 - val_accuracy: 0.9365
# Epoch 55/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.2004 - accuracy: 0.9423 - val_loss: 0.2151 - val_accuracy: 0.9365
# Epoch 56/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.1984 - accuracy: 0.9426 - val_loss: 0.2127 - val_accuracy: 0.9377
# Epoch 57/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1966 - accuracy: 0.9433 - val_loss: 0.2108 - val_accuracy: 0.9378
# Epoch 58/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1947 - accuracy: 0.9442 - val_loss: 0.2102 - val_accuracy: 0.9383
# Epoch 59/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.1928 - accuracy: 0.9446 - val_loss: 0.2077 - val_accuracy: 0.9390
# Epoch 60/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1906 - accuracy: 0.9450 - val_loss: 0.2075 - val_accuracy: 0.9388
# Epoch 61/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1890 - accuracy: 0.9453 - val_loss: 0.2044 - val_accuracy: 0.9408
# Epoch 62/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1872 - accuracy: 0.9462 - val_loss: 0.2036 - val_accuracy: 0.9393
# Epoch 63/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1855 - accuracy: 0.9462 - val_loss: 0.2008 - val_accuracy: 0.9412
# Epoch 64/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1835 - accuracy: 0.9472 - val_loss: 0.1994 - val_accuracy: 0.9408
# Epoch 65/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.1819 - accuracy: 0.9476 - val_loss: 0.1983 - val_accuracy: 0.9428
# Epoch 66/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1802 - accuracy: 0.9476 - val_loss: 0.1965 - val_accuracy: 0.9435
# Epoch 67/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1784 - accuracy: 0.9487 - val_loss: 0.1957 - val_accuracy: 0.9442
# Epoch 68/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1766 - accuracy: 0.9491 - val_loss: 0.1943 - val_accuracy: 0.9433
# Epoch 69/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1750 - accuracy: 0.9495 - val_loss: 0.1934 - val_accuracy: 0.9430
# Epoch 70/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.1735 - accuracy: 0.9497 - val_loss: 0.1913 - val_accuracy: 0.9440
# Epoch 71/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1719 - accuracy: 0.9502 - val_loss: 0.1912 - val_accuracy: 0.9455
# Epoch 72/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1704 - accuracy: 0.9505 - val_loss: 0.1875 - val_accuracy: 0.9460
# Epoch 73/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1686 - accuracy: 0.9511 - val_loss: 0.1877 - val_accuracy: 0.9437
# Epoch 74/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1671 - accuracy: 0.9513 - val_loss: 0.1850 - val_accuracy: 0.9468
# Epoch 75/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1657 - accuracy: 0.9522 - val_loss: 0.1840 - val_accuracy: 0.9458
# Epoch 76/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1641 - accuracy: 0.9524 - val_loss: 0.1838 - val_accuracy: 0.9468
# Epoch 77/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1626 - accuracy: 0.9528 - val_loss: 0.1811 - val_accuracy: 0.9460
# Epoch 78/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1611 - accuracy: 0.9539 - val_loss: 0.1812 - val_accuracy: 0.9477
# Epoch 79/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1595 - accuracy: 0.9538 - val_loss: 0.1795 - val_accuracy: 0.9473
# Epoch 80/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1582 - accuracy: 0.9541 - val_loss: 0.1779 - val_accuracy: 0.9478
# Epoch 81/100
# 1688/1688 [==============================] - 8s 4ms/step - loss: 0.1568 - accuracy: 0.9543 - val_loss: 0.1767 - val_accuracy: 0.9478
# Epoch 82/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.1556 - accuracy: 0.9550 - val_loss: 0.1755 - val_accuracy: 0.9495
# Epoch 83/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1540 - accuracy: 0.9557 - val_loss: 0.1744 - val_accuracy: 0.9490
# Epoch 84/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1529 - accuracy: 0.9557 - val_loss: 0.1729 - val_accuracy: 0.9487
# Epoch 85/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1514 - accuracy: 0.9562 - val_loss: 0.1724 - val_accuracy: 0.9495
# Epoch 86/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1500 - accuracy: 0.9569 - val_loss: 0.1708 - val_accuracy: 0.9503
# Epoch 87/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1487 - accuracy: 0.9570 - val_loss: 0.1703 - val_accuracy: 0.9508
# Epoch 88/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1475 - accuracy: 0.9573 - val_loss: 0.1694 - val_accuracy: 0.9507
# Epoch 89/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1463 - accuracy: 0.9574 - val_loss: 0.1677 - val_accuracy: 0.9507
# Epoch 90/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1450 - accuracy: 0.9580 - val_loss: 0.1661 - val_accuracy: 0.9517
# Epoch 91/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1437 - accuracy: 0.9584 - val_loss: 0.1654 - val_accuracy: 0.9520
# Epoch 92/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1424 - accuracy: 0.9588 - val_loss: 0.1645 - val_accuracy: 0.9523
# Epoch 93/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1414 - accuracy: 0.9591 - val_loss: 0.1638 - val_accuracy: 0.9518
# Epoch 94/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1401 - accuracy: 0.9593 - val_loss: 0.1631 - val_accuracy: 0.9518
# Epoch 95/100
# 1688/1688 [==============================] - 10s 6ms/step - loss: 0.1388 - accuracy: 0.9596 - val_loss: 0.1612 - val_accuracy: 0.9532
# Epoch 96/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1375 - accuracy: 0.9603 - val_loss: 0.1624 - val_accuracy: 0.9522
# Epoch 97/100
# 1688/1688 [==============================] - 11s 7ms/step - loss: 0.1367 - accuracy: 0.9604 - val_loss: 0.1592 - val_accuracy: 0.9537
# Epoch 98/100
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.1355 - accuracy: 0.9606 - val_loss: 0.1579 - val_accuracy: 0.9543
# Epoch 99/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1342 - accuracy: 0.9617 - val_loss: 0.1581 - val_accuracy: 0.9532
# Epoch 100/100
# 1688/1688 [==============================] - 9s 6ms/step - loss: 0.1333 - accuracy: 0.9611 - val_loss: 0.1573 - val_accuracy: 0.9545
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1500 - accuracy: 0.9547
# Loss on test data: 0.14997245371341705
# Accuracy on test data: 0.9546999931335449
# 1/1 [==============================] - 0s 94ms/step
# NN output: [[2.6040095e-09 9.9666852e-01 7.4406926e-05 1.0829077e-03 2.3158487e-05
#   4.1534760e-05 8.1603630e-06 1.3447354e-03 1.0414082e-04 6.5227761e-04]]
# Real mark:  1
# NN answer:  1
# 1/1 [==============================] - 0s 22ms/step
# I think it's  2
